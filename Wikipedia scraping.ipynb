# %% [markdown]
# # Different possibilities
# There is different possibilities out there:
#
# - Use WikiData: contains a lot of data from Wikipedia (and other) in a relational style. However, data about politician/big swiss companies aren't part of the Wikidata
# - `Wikipedia` python module (or, more generally, the MediaWiki API) where one can find more structured information. However, in this case, most of the features aren't useful (at least at first)
# - Scrape page directly. This solution will be tried first
#
# # Scraping Wikipedia

# %%
import requests                       # HTTP requests lib
from bs4 import BeautifulSoup         # HTML parsing
import pandas as pd                   # Data handling
import lxml

WIKIPEDIA_URL = "https://en.wikipedia.org/wiki/List_of_Swiss_companies_by_revenue"

page = BeautifulSoup(requests.get(WIKIPEDIA_URL).content, "html.parser")
#print(page.prettify())

content_div = page.find('div', {'id':'mw-content-text'}) 

table_class_target = set('wikitable sortable'.split(' '))
found_tables = []

def parse_table(table):
    lines = table.find_all('tr')

    # Extract column names
    colnames = [str(name.find('b').text) for name in lines[0].find_all('td')]
    
    # Simple cleanup of the column names
    colnames = [elem.split('\n')[0] for elem in colnames]
    
    # Parse other lines
    content = []
    for line in lines[1:]:
        content.append([e.text for e in line.find_all('td')])
    
    return pd.DataFrame(data=content, columns=colnames)

for table in content_div.find_all('table') :
    classes_found = set(table['class'])
    if table_class_target <= classes_found:
        # Table to parse
        found_tables.append(parse_table(table))

# %% [markdown]
# This scrape all the wikitable from the page, then some cleaning need to be done
#
# ## Largest companies

# %%
largest_companies = found_tables[0]
largest_companies
# Out:
#     Rank                      Name    Headquarters  Revenue Net income  \
# 0     1.                  Glencore            Baar  119 938
# 1     2.                    Nestlé           Vevey   91 075      7 995
# 2     3.                  Novartis           Basel   42 455      8 093
# 3     4.                     Roche           Basel   35 511      2 390
# 4     5.                       ABB          Zurich   29 169        955
# 5     6.                    Adecco        Chéserex   28 534        706
# 6     7.                    Migros          Zurich   20 385        699
# 7     8.                    Holcim            Jona   18 468      1 818
# 8     9.  Cargill International SA          Geneva   18 275
# 9    10.                      Coop           Basel   14 901        270
# 10   11.             Kühne + Nagel    Schindellegi   14 048        315
# 11   12.   Mercuria Energy Trading          Geneva   11 200        200
# 12   13.                  Syngenta           Basel   10 681        779
# 13   14.                   Xstrata             Zug   10 609      2 249
# 14   15.                  Swisscom            Bern    9 732      2 346
# 15   16.                 Schindler          Ebikon    8 870        401
# 16   17.     Atel / Motor-Columbus           Olten    8 580        413
# 17   18.             Alstom Suisse           Baden    8 500
# 18   19.                 Panalpina           Basel    8 293        120
# 19   20.                  Liebherr           Bulle    8 270
# 20   21.                  Clariant         Muttenz    8 181        192
# 21   22.                  La Poste            Bern    7 499        811
# 22   23.        DKSH Management AG          Zurich    7 454
# 23   24.                      Ciba           Basel    7 419       -256
# 24   25.                       CFF            Bern    7 087       -166
# 25   26.                      Axpo           Baden    6 716        571
# 26   27.                 Richemont          Geneva    6 716
# 27   28.             Globus-Cosmos      Montagnola    5 600
# 28   29.                    Swatch          Bienne    4 497        621
# 29   30.                    Fenaco            Bern    4 380         54
# ..   ...                       ...             ...      ...        ...
# 70   71.                   Sunrise          Zurich    1 991        208
# 71   72.                ALSO Group       Hergiswil    1 980         17
# 72   73.                    Franke         Aarburg    1 959
# 73   74.            Mettler-Toledo      Greifensee    1 953        143
# 74   75.                 Emil Frey          Zurich    1 950
# 75   76.         Bucher Industries  Niederweningen    1 948         86
# 76   77.           BKW FMB Energie            Bern    1 931        306
# 77   78.                   Geberit      Rapperswil    1 922
# 78   79.                 Hotelplan      Glattbrugg    1 728         16
# 79   80.               Esso Suisse          Zurich    1 720
# 80   81.                     Forbo            Baar    1 702
# 81   82.                    Nuance      Glattbrugg    1 690
# 82   83.                  Cementia          Zurich    1 650
# 83   84.                 BP Suisse             Zug    1 634         32
# 84   85.                    Unaxis       Pfäffikon    1 605
# 85   86.       SRG SSR idée suisse            Bern    1 591       -0.3
# 86   87.                     Bobst          Prilly    1 591         46
# 87   88.    Hewlett-Packard Suisse       Dübendorf    1 550
# 88   89.              Krupp Presta          Eschen    1 550
# 89   90.              Allied Steel          Lugano    1 519         33
# 90   91.                    Bühler           Uzwil    1 502         72
# 91   92.                 Swissport         Opfikon    1 499
# 92   93.                    Migrol          Zurich    1 496
# 93   94.              Shell Suisse            Baar    1 466
# 94   95.                      Bell           Basel    1 443         35
# 95   96.    DaimlerChrysler Suisse       Schlieren    1 427
# 96   97.                     Sicpa          Prilly    1 400
# 97   98.                BMW Suisse       Dielsdorf    1 392
# 98   99.             Steiner Group          Zurich    1 379
# 99  100.               EOS Holding        Lausanne    1 371         51
#
#      Employees                           Industry                Director
# 0   181 000[1]                  commodity trading
# 1      253 000                   agriculture/food  Peter Brabeck-Letmathe
# 2       90 924            chemical/pharmaceutical
# 3       68 218            chemical/pharmaceutical
# 4      104 000                        engineering
# 5       33 000                       temp workers
# 6       59 934                    retail/services
# 7       59 901             construction materials
# 8          475                  commodity trading
# 9       37 370                    retail/services
# 10      25 607  international transport/logistics
# 11                                      petroleum
# 12      19 337            chemical/pharmaceutical
# 13      17 000                             mining
# 14      16 088                 telecommunications
# 15      40 385                        engineering
# 16       8 649     energy production/distribution
# 17       4 500          engineering/manufacturing
# 18      13 583   international shipping/logistics
# 19      23 762                        engineering
# 20      23 383            chemical/pharmaceutical
# 21      41 073                            service
# 22      20 500                      import/export
# 23      19 105            chemical/pharmaceutical
# 24      28 383         public transport/railroads
# 25       2 990     energy production/distribution
# 26
# 27       5 000              travel agency/tourism
# 28      20 650                        watchmaking
# 29       7 244                             retail
# ..         ...                                ...                     ...
# 70       2 300                 telecommunications
# 71         623                          computers
# 72       7 040              electrical appliances
# 73       8 700                              tools
# 74       2 144           automobile sales/imports
# 75       6 874                        engineering
# 76       2 120     energy production/distribution
# 77       5 162
# 78       3 109              travel agency/tourism
# 79         155                          petroleum
# 80       5 538            carpets/floor coverings
# 81       4 936
# 82       6 000             construction materials
# 83         134                          petroleum
# 84       6 434
# 85                                        service
# 86       5 587                        engineering
# 87       1 400                          computers
# 88       4 600                        engineering
# 89          70                      import/export
# 90       6 266                        engineering
# 91      21 000                            service
# 92         285                          petroleum
# 93         171                          petroleum
# 94       3 326                      meat products
# 95         403           automobile sales/imports
# 96       3 400          chemicals/pharmaceuticals
# 97         299           automobile sales/imports
# 98         500                general contractors
# 99         333     energy production/distribution
#
# [100 rows x 8 columns]

# %%
def set_rank_as_index(df, colname='Rank'):
    if df[colname].dtype==object:
        df[colname] = df[colname].apply(lambda x: int(x.split('.')[0]))
        df.set_index(colname, inplace=True)

set_rank_as_index(largest_companies)
largest_companies
# Out:
#                           Name    Headquarters  Revenue Net income  \
# Rank
# 1                     Glencore            Baar  119 938
# 2                       Nestlé           Vevey   91 075      7 995
# 3                     Novartis           Basel   42 455      8 093
# 4                        Roche           Basel   35 511      2 390
# 5                          ABB          Zurich   29 169        955
# 6                       Adecco        Chéserex   28 534        706
# 7                       Migros          Zurich   20 385        699
# 8                       Holcim            Jona   18 468      1 818
# 9     Cargill International SA          Geneva   18 275
# 10                        Coop           Basel   14 901        270
# 11               Kühne + Nagel    Schindellegi   14 048        315
# 12     Mercuria Energy Trading          Geneva   11 200        200
# 13                    Syngenta           Basel   10 681        779
# 14                     Xstrata             Zug   10 609      2 249
# 15                    Swisscom            Bern    9 732      2 346
# 16                   Schindler          Ebikon    8 870        401
# 17       Atel / Motor-Columbus           Olten    8 580        413
# 18               Alstom Suisse           Baden    8 500
# 19                   Panalpina           Basel    8 293        120
# 20                    Liebherr           Bulle    8 270
# 21                    Clariant         Muttenz    8 181        192
# 22                    La Poste            Bern    7 499        811
# 23          DKSH Management AG          Zurich    7 454
# 24                        Ciba           Basel    7 419       -256
# 25                         CFF            Bern    7 087       -166
# 26                        Axpo           Baden    6 716        571
# 27                   Richemont          Geneva    6 716
# 28               Globus-Cosmos      Montagnola    5 600
# 29                      Swatch          Bienne    4 497        621
# 30                      Fenaco            Bern    4 380         54
# ...                        ...             ...      ...        ...
# 71                     Sunrise          Zurich    1 991        208
# 72                  ALSO Group       Hergiswil    1 980         17
# 73                      Franke         Aarburg    1 959
# 74              Mettler-Toledo      Greifensee    1 953        143
# 75                   Emil Frey          Zurich    1 950
# 76           Bucher Industries  Niederweningen    1 948         86
# 77             BKW FMB Energie            Bern    1 931        306
# 78                     Geberit      Rapperswil    1 922
# 79                   Hotelplan      Glattbrugg    1 728         16
# 80                 Esso Suisse          Zurich    1 720
# 81                       Forbo            Baar    1 702
# 82                      Nuance      Glattbrugg    1 690
# 83                    Cementia          Zurich    1 650
# 84                   BP Suisse             Zug    1 634         32
# 85                      Unaxis       Pfäffikon    1 605
# 86         SRG SSR idée suisse            Bern    1 591       -0.3
# 87                       Bobst          Prilly    1 591         46
# 88      Hewlett-Packard Suisse       Dübendorf    1 550
# 89                Krupp Presta          Eschen    1 550
# 90                Allied Steel          Lugano    1 519         33
# 91                      Bühler           Uzwil    1 502         72
# 92                   Swissport         Opfikon    1 499
# 93                      Migrol          Zurich    1 496
# 94                Shell Suisse            Baar    1 466
# 95                        Bell           Basel    1 443         35
# 96      DaimlerChrysler Suisse       Schlieren    1 427
# 97                       Sicpa          Prilly    1 400
# 98                  BMW Suisse       Dielsdorf    1 392
# 99               Steiner Group          Zurich    1 379
# 100                EOS Holding        Lausanne    1 371         51
#
#        Employees                           Industry                Director
# Rank
# 1     181 000[1]                  commodity trading
# 2        253 000                   agriculture/food  Peter Brabeck-Letmathe
# 3         90 924            chemical/pharmaceutical
# 4         68 218            chemical/pharmaceutical
# 5        104 000                        engineering
# 6         33 000                       temp workers
# 7         59 934                    retail/services
# 8         59 901             construction materials
# 9            475                  commodity trading
# 10        37 370                    retail/services
# 11        25 607  international transport/logistics
# 12                                        petroleum
# 13        19 337            chemical/pharmaceutical
# 14        17 000                             mining
# 15        16 088                 telecommunications
# 16        40 385                        engineering
# 17         8 649     energy production/distribution
# 18         4 500          engineering/manufacturing
# 19        13 583   international shipping/logistics
# 20        23 762                        engineering
# 21        23 383            chemical/pharmaceutical
# 22        41 073                            service
# 23        20 500                      import/export
# 24        19 105            chemical/pharmaceutical
# 25        28 383         public transport/railroads
# 26         2 990     energy production/distribution
# 27
# 28         5 000              travel agency/tourism
# 29        20 650                        watchmaking
# 30         7 244                             retail
# ...          ...                                ...                     ...
# 71         2 300                 telecommunications
# 72           623                          computers
# 73         7 040              electrical appliances
# 74         8 700                              tools
# 75         2 144           automobile sales/imports
# 76         6 874                        engineering
# 77         2 120     energy production/distribution
# 78         5 162
# 79         3 109              travel agency/tourism
# 80           155                          petroleum
# 81         5 538            carpets/floor coverings
# 82         4 936
# 83         6 000             construction materials
# 84           134                          petroleum
# 85         6 434
# 86                                          service
# 87         5 587                        engineering
# 88         1 400                          computers
# 89         4 600                        engineering
# 90            70                      import/export
# 91         6 266                        engineering
# 92        21 000                            service
# 93           285                          petroleum
# 94           171                          petroleum
# 95         3 326                      meat products
# 96           403           automobile sales/imports
# 97         3 400          chemicals/pharmaceuticals
# 98           299           automobile sales/imports
# 99           500                general contractors
# 100          333     energy production/distribution
#
# [100 rows x 7 columns]

# %%
largest_companies.dtypes
# Out:
# Name            object
# Headquarters    object
# Revenue         object
# Net income      object
# Employees       object
# Industry        object
# Director        object
# dtype: object

# %%
def custom_to_numeric(column, silently=True):
    if column.dtype != object:
        return column
    
    # Clean cells
    def clean(s: str):
        # Remove spaces
        s = ''.join(s.split())
        
        # Removes reference (`[d]`)
        return s.split('[')[0]
    
    c = column.apply(clean)
    
    # Convert to int
    conversion_force = 'coerc' if silently else 'raise'
    return pd.to_numeric(c, conversion_force)
    
col_to_convert = ['Revenue', 'Net income', 'Employees']

for c in col_to_convert:
    largest_companies[c] = custom_to_numeric(largest_companies[c], False)

largest_companies.dtypes
# Out:
# Name             object
# Headquarters     object
# Revenue           int64
# Net income      float64
# Employees       float64
# Industry         object
# Director         object
# dtype: object

# %% [markdown]
# Where the fields look well parsed.
#
# ## Largest banks
# Let do it again for largest banks

# %%
largest_banks = found_tables[1]
largest_banks
# Out:
#    Ranked                        Name Headquarters Total assets  Income  \
# 0      1.                         UBS        Basel    2 060 250  14 690
# 1      2.               Credit Suisse       Zurich    1 339 052   5 850
# 2      3.                  Raiffeisen   St. Gallen      108 187     608
# 3      4.        Zürcher Kantonalbank       Zurich       85 914     810
# 4      5.  HSBC Private Bank (Suisse)       Geneva       54 012     374
# 5      6.        BNP Paribas (Suisse)       Geneva       37 657     309
# 6      7.   Banque cantonale vaudoise     Lausanne       34 875     457
# 7      8.           Julius Baer Group       Zurich       28 648     144
# 8      9.               Banque Migros       Zurich       28 000      87
# 9     10.         Basler Kantonalbank        Basel       24 654     263
# 10    11.    Crédit Agricole (Suisse)       Geneva       24 512     154
# 11    12.         Berner Kantonalbank         Bern       20 724      85
# 12    13.   Saint Galler Kantonalbank   St. Gallen       19 117     168
# 13    14.       Luzerner Kantonalbank      Lucerne       18 879     120
# 14    15.       Coutts Bank von Ernst       Zurich       18 799      44
# 15    16.          Neur Aargauer Bank        Aarau       17 526     138
# 16    17.          Valiant Holding AG      Lucerne       17 138     122
# 17    18.       Union Bancaire Privée       Geneva       15 901     326
# 18    19.    Aargauische Kantonalbank   Laufenburg       15 546      84
# 19    20.                                   Lugano       15 237      82
#
#    Employees                               Manager
# 0     69 569  Marcel Ospel, Basler, 2008 abgewählt
# 1     63 523
# 2      6 549
# 3      4 276
# 4      1 929
# 5      1 736
# 6      2 349
# 7      3 427
# 8      1 124
# 9      1 348
# 10     1 119
# 11     1 441
# 12       957
# 13       951
# 14       975
# 15       797
# 16       960
# 17     1 168
# 18       641
# 19     1 150

# %%
set_rank_as_index(largest_banks, 'Ranked')
largest_banks
# Out:
#                               Name Headquarters Total assets  Income  \
# Ranked
# 1                              UBS        Basel    2 060 250  14 690
# 2                    Credit Suisse       Zurich    1 339 052   5 850
# 3                       Raiffeisen   St. Gallen      108 187     608
# 4             Zürcher Kantonalbank       Zurich       85 914     810
# 5       HSBC Private Bank (Suisse)       Geneva       54 012     374
# 6             BNP Paribas (Suisse)       Geneva       37 657     309
# 7        Banque cantonale vaudoise     Lausanne       34 875     457
# 8                Julius Baer Group       Zurich       28 648     144
# 9                    Banque Migros       Zurich       28 000      87
# 10             Basler Kantonalbank        Basel       24 654     263
# 11        Crédit Agricole (Suisse)       Geneva       24 512     154
# 12             Berner Kantonalbank         Bern       20 724      85
# 13       Saint Galler Kantonalbank   St. Gallen       19 117     168
# 14           Luzerner Kantonalbank      Lucerne       18 879     120
# 15           Coutts Bank von Ernst       Zurich       18 799      44
# 16              Neur Aargauer Bank        Aarau       17 526     138
# 17              Valiant Holding AG      Lucerne       17 138     122
# 18           Union Bancaire Privée       Geneva       15 901     326
# 19        Aargauische Kantonalbank   Laufenburg       15 546      84
# 20                                       Lugano       15 237      82
#
#        Employees                               Manager
# Ranked
# 1         69 569  Marcel Ospel, Basler, 2008 abgewählt
# 2         63 523
# 3          6 549
# 4          4 276
# 5          1 929
# 6          1 736
# 7          2 349
# 8          3 427
# 9          1 124
# 10         1 348
# 11         1 119
# 12         1 441
# 13           957
# 14           951
# 15           975
# 16           797
# 17           960
# 18         1 168
# 19           641
# 20         1 150

# %%
col_to_convert = ['Total assets', 'Income', 'Employees']
for c in col_to_convert:
    largest_banks[c] = custom_to_numeric(largest_banks[c])
    
largest_banks
# Out:
#                               Name Headquarters  Total assets  Income  \
# Ranked
# 1                              UBS        Basel       2060250   14690
# 2                    Credit Suisse       Zurich       1339052    5850
# 3                       Raiffeisen   St. Gallen        108187     608
# 4             Zürcher Kantonalbank       Zurich         85914     810
# 5       HSBC Private Bank (Suisse)       Geneva         54012     374
# 6             BNP Paribas (Suisse)       Geneva         37657     309
# 7        Banque cantonale vaudoise     Lausanne         34875     457
# 8                Julius Baer Group       Zurich         28648     144
# 9                    Banque Migros       Zurich         28000      87
# 10             Basler Kantonalbank        Basel         24654     263
# 11        Crédit Agricole (Suisse)       Geneva         24512     154
# 12             Berner Kantonalbank         Bern         20724      85
# 13       Saint Galler Kantonalbank   St. Gallen         19117     168
# 14           Luzerner Kantonalbank      Lucerne         18879     120
# 15           Coutts Bank von Ernst       Zurich         18799      44
# 16              Neur Aargauer Bank        Aarau         17526     138
# 17              Valiant Holding AG      Lucerne         17138     122
# 18           Union Bancaire Privée       Geneva         15901     326
# 19        Aargauische Kantonalbank   Laufenburg         15546      84
# 20                                       Lugano         15237      82
#
#         Employees                               Manager
# Ranked
# 1           69569  Marcel Ospel, Basler, 2008 abgewählt
# 2           63523
# 3            6549
# 4            4276
# 5            1929
# 6            1736
# 7            2349
# 8            3427
# 9            1124
# 10           1348
# 11           1119
# 12           1441
# 13            957
# 14            951
# 15            975
# 16            797
# 17            960
# 18           1168
# 19            641
# 20           1150

# %%
largest_banks.dtypes
# Out:
# Name            object
# Headquarters    object
# Total assets     int64
# Income           int64
# Employees        int64
# Manager         object
# dtype: object

# %% [markdown]
# ## And once again for insurances

# %%
largest_insurances = found_tables[2]
largest_insurances
# Out:
#   Rang                       Name Headquarters  \
# 0   1.  Zurich Financial Services       Zurich
# 1   2.                   Swiss Re       Zurich
# 2   3.           Winterthur Group   Winterthur
# 3   4.                 Swiss Life       Zurich
# 4   5.                    Bâloise        Basel
# 5   6.            Helvetia Patria   St. Gallen
# 6   7.                       Suva      Lucerne
# 7   8.    Groupe Allianz (Suisse)
# 8   9.               La Mobilière         Bern
# 9  10.        Vaudoise Assurances     Lausanne
#
#   Ranked by gross inflow of premimus Net profit Employees Manager
# 0                             61 678      4 388
# 1                             27 779      1 451
# 2                             21 269      1 061
# 3                             20 211        874
# 4                              6 839        403
# 5                              5 176        301
# 6                              4 149
# 7                              3 631        258
# 8                              2 608        272
# 9                              1 955         44

# %%
set_rank_as_index(largest_insurances, 'Rang')
largest_insurances
# Out:
#                            Name Headquarters  \
# Rang
# 1     Zurich Financial Services       Zurich
# 2                      Swiss Re       Zurich
# 3              Winterthur Group   Winterthur
# 4                    Swiss Life       Zurich
# 5                       Bâloise        Basel
# 6               Helvetia Patria   St. Gallen
# 7                          Suva      Lucerne
# 8       Groupe Allianz (Suisse)
# 9                  La Mobilière         Bern
# 10          Vaudoise Assurances     Lausanne
#
#      Ranked by gross inflow of premimus Net profit Employees Manager
# Rang
# 1                                61 678      4 388
# 2                                27 779      1 451
# 3                                21 269      1 061
# 4                                20 211        874
# 5                                 6 839        403
# 6                                 5 176        301
# 7                                 4 149
# 8                                 3 631        258
# 9                                 2 608        272
# 10                                1 955         44

# %%
col_to_convert = ['Ranked by gross inflow of premimus', 'Net profit']
for c in col_to_convert:
    largest_insurances[c] = custom_to_numeric(largest_insurances[c])
    
largest_insurances
# Out:
#                            Name Headquarters  \
# Rang
# 1     Zurich Financial Services       Zurich
# 2                      Swiss Re       Zurich
# 3              Winterthur Group   Winterthur
# 4                    Swiss Life       Zurich
# 5                       Bâloise        Basel
# 6               Helvetia Patria   St. Gallen
# 7                          Suva      Lucerne
# 8       Groupe Allianz (Suisse)
# 9                  La Mobilière         Bern
# 10          Vaudoise Assurances     Lausanne
#
#       Ranked by gross inflow of premimus  Net profit Employees Manager
# Rang
# 1                                  61678      4388.0
# 2                                  27779      1451.0
# 3                                  21269      1061.0
# 4                                  20211       874.0
# 5                                   6839       403.0
# 6                                   5176       301.0
# 7                                   4149         NaN
# 8                                   3631       258.0
# 9                                   2608       272.0
# 10                                  1955        44.0

# %%
largest_insurances.dtypes
# Out:
# Name                                   object
# Headquarters                           object
# Ranked by gross inflow of premimus      int64
# Net profit                            float64
# Employees                              object
# Manager                                object
# dtype: object

# %% [markdown]
# # Save scrape data

# %%
import os

# %%
DATA_DIR = 'data'

if not os.path.exists(DATA_DIR):
    print('Create data directory')
    os.mkdir(DATA_DIR)
    
to_save = {
    'largest_companies.csv': largest_companies,
    'largest_insurances.csv': largest_insurances,
    'largest_banks.csv': largest_banks,
}

for k, v in to_save:
    v.to_csv(k)
