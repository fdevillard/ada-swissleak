# %% [markdown]
# # Lookup politicians and their interests in the Panama Papers
#
# Using the data we obtained in the previous notebooks, we will now look up those politicians and their interests in the panama papers.

# %%
# %matplotlib inline
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# New imports for using Neo4j
import networkx as nx
#from py2neo import Graph
from helpers.vis import draw
# %set_env NEO4J_URL http://neo4j:neo4j2@localhost:7474
#%load_ext cypher
# Out:
# env: NEO4J_URL=http://neo4j:neo4j2@localhost:7474

# %%
graph = Graph('http://neo4j:neo4j2@localhost:7474')

# %%
# function to search columns of a pandas dataframe
def search(df, col, words):
    cond = [df[col].str.contains('(?<![\w\d])'+w+'(?![\w\d])', case=False, na=False) for w in words]
    return df[np.logical_and.reduce(cond)]

# split a string in words with no ponctuation
import re
def split(str):
    return re.split('\W+', str)

# %%
# load datasets
from helpers.swiss_codes import filter_swiss
# 1. officers
officers = pd.read_csv('data/Officers.csv', header=0, low_memory=False)
swiss_officers = filter_swiss(officers, process_address=False)
del officers
# 2. entities
entities = pd.read_csv('data/Entities.csv', header=0, low_memory=False)
swiss_entities = filter_swiss(entities)
del entities
# 3. intermediaries
inter = pd.read_csv('data/Intermediaries.csv', header=0, low_memory=False)
swiss_inter = filter_swiss(inter)
del inter

# %% [markdown]
# ## All interests

# %%
all_interests = pd.read_json('data/all_interests.json')
all_interests
# Out:
#              data_source first_name  index  \
# 0     federal_parliament  Christoph     68
# 1     federal_parliament  Christoph     68
# 10    federal_parliament     Ulrich     85
# 100   federal_parliament      Kathy    439
# 1000  federal_parliament     Albert   3372
# 1001  federal_parliament     Albert   3372
# 1002  federal_parliament     Albert   3372
# 1003  federal_parliament     Albert   3372
# 1004  federal_parliament     Albert   3372
# 1005  federal_parliament     Albert   3372
# 1006  federal_parliament     Stefan   3373
# 1007  federal_parliament     Stefan   3373
# 1008  federal_parliament     Stefan   3373
# 1009  federal_parliament     Stefan   3373
# 101   federal_parliament      Kathy    439
# 1010  federal_parliament     Stefan   3373
# 1011  federal_parliament     Stefan   3373
# 1012  federal_parliament     Stefan   3373
# 1013  federal_parliament     Stefan   3373
# 1014  federal_parliament     Stefan   3373
# 1015  federal_parliament     Stefan   3373
# 1016  federal_parliament     Daniel   3374
# 1017  federal_parliament     Daniel   3374
# 1018  federal_parliament     Daniel   3374
# 1019  federal_parliament     Daniel   3374
# 102   federal_parliament      Kathy    439
# 1020  federal_parliament     Daniel   3374
# 1021  federal_parliament     Daniel   3374
# 1022  federal_parliament     Daniel   3374
# 1023  federal_parliament     Daniel   3374
# ...                  ...        ...    ...
# 972   federal_parliament   Matthias   3367
# 973   federal_parliament   Matthias   3367
# 974   federal_parliament     Thomas   3369
# 975   federal_parliament     Thomas   3369
# 976   federal_parliament     Thomas   3369
# 977   federal_parliament     Thomas   3369
# 978   federal_parliament     Thomas   3369
# 979   federal_parliament     Thomas   3369
# 98    federal_parliament      Kathy    439
# 980   federal_parliament     Thomas   3369
# 981   federal_parliament     Thomas   3369
# 982   federal_parliament     Thomas   3369
# 983   federal_parliament     Thomas   3369
# 984   federal_parliament     Thomas   3369
# 985   federal_parliament     Thomas   3369
# 986   federal_parliament     Thomas   3369
# 987   federal_parliament     Thomas   3369
# 988   federal_parliament     Markus   3370
# 989   federal_parliament     Markus   3370
# 99    federal_parliament      Kathy    439
# 990   federal_parliament     Markus   3370
# 991   federal_parliament     Thomas   3371
# 992   federal_parliament     Thomas   3371
# 993   federal_parliament     Thomas   3371
# 994   federal_parliament     Thomas   3371
# 995   federal_parliament     Thomas   3371
# 996   federal_parliament     Albert   3372
# 997   federal_parliament     Albert   3372
# 998   federal_parliament     Albert   3372
# 999   federal_parliament     Albert   3372
#
#                                           interest_name     last_name  \
# 0                               Kraftwerk Birsfelden AG        Eymann
# 1                   Universität Basel (Universitätsrat)        Eymann
# 10                                       Online Easy AG  Giezendanner
# 100   Organe consultatif sur les changements climati...        Riklin
# 1000  IG Volkskultur Schweiz und Fürstentum Liechten...        Vitali
# 1001  Pro Senectute Kanton Luzern (Stiftungsversamml...        Vitali
# 1002                               Energie Oberkirch AG        Vitali
# 1003              Schweizer Verband für Rechnungslegung        Vitali
# 1004                                     Wohnen Schweiz        Vitali
# 1005                   Förderverein Luzern Volksschulen        Vitali
# 1006                                  Rhätische Bahn AG        Engler
# 1007                                   Grischelektra AG        Engler
# 1008                           Lazzarini Beteiligung AG        Engler
# 1009                                 Lazzarini (Bau) AG        Engler
# 101     Schweizerische Vereinigung für Geothermie (SVG)        Riklin
# 1010                                Schweizer Berghilfe        Engler
# 1011  Gebäudeversicherung Graubünden (Verwaltungskom...        Engler
# 1012             Schweizerische Mobiliar Genossenschaft        Engler
# 1013                                       SchweizMobil        Engler
# 1014                     EWD Elektrizitätswerk Davos AG        Engler
# 1015                                     Später Chur AG        Engler
# 1016                             Glattstrom Buchholz AG       Fässler
# 1017                                        plusimmo AG       Fässler
# 1018                           Schwendner Chölbi Verein       Fässler
# 1019                Verein Appenzellerland Tourismus AI       Fässler
# 102                                               SCAHT        Riklin
# 1020                           Appenzeller Kantonalbank       Fässler
# 1021  Konferenz der kantonalen Direktoren des öffent...       Fässler
# 1022  Konferenz kantonaler Volkswirtschaftsdirektore...       Fässler
# 1023                  Internationale Bodensee Konferenz       Fässler
# ...                                                 ...           ...
# 972                                 Sternwarte Uecht/BE     Aebischer
# 973                                       Espoir Zürich     Aebischer
# 974                           Autobus AG Liestal (AAGL)    de Courten
# 975                Raiffeisenbank Liestal-Oberbaselbiet    de Courten
# 976                             Elektra Baselland (EBL)    de Courten
# 977               Abbundcenter Nordwestschweiz AG (ANW)    de Courten
# 978            Wohlfahrtsstiftung der Elektra Baselland    de Courten
# 979                                            politcom    de Courten
# 98    Schweizerische Gesellschaft für Aussenpolitik ...        Riklin
# 980                                       Intergenerika    de Courten
# 981             Komitee für ein selbständiges Baselbiet    de Courten
# 982                     SWISS REHA (Politischer Beirat)    de Courten
# 983   Verband Schweiz. Bürgergemeinden und Korporati...    de Courten
# 984                                        SPEDLOGSWISS    de Courten
# 985         IG biomedizinische Forschung und Innovation    de Courten
# 986                                          Swisscable    de Courten
# 987               Stiftung Schweizerische Wildtierwarte    de Courten
# 988                       Schweizerischer Bauernverband        Ritter
# 989   Pensionskasse des Schweizerischen Bauernverbandes        Ritter
# 99    Gesellschaft für Schweizerische Kunstgeschicht...        Riklin
# 990                            Haus des Schweizerbauern        Ritter
# 991                               Aeschi & Company GmbH        Aeschi
# 992       Stiftung für junge Auslandschweizer (Revisor)        Aeschi
# 993       Vereinigung der privaten Aktiengesellschaften        Aeschi
# 994                                    Swiss Police ICT        Aeschi
# 995                   Aktion Freiheit und Verantwortung        Aeschi
# 996                                  Vitali + Müller AG        Vitali
# 997                                Vitali Treuhand GmbH        Vitali
# 998              Stiftung für Schwerstbehinderte (SSBL)        Vitali
# 999                Aufsichtskommission IV-Stelle Luzern        Vitali
#
#                        position
# 0                        Membre
# 1                        Membre
# 10            Vice-président(e)
# 100                Président(e)
# 1000               Président(e)
# 1001                     Membre
# 1002               Président(e)
# 1003                     Membre
# 1004                     Membre
# 1005                     Membre
# 1006               Président(e)
# 1007               Président(e)
# 1008               Président(e)
# 1009               Président(e)
# 101                      Membre
# 1010  Consultant/e specialisé/e
# 1011                     Membre
# 1012                 Délégué(e)
# 1013               Président(e)
# 1014               Président(e)
# 1015                     Membre
# 1016               Président(e)
# 1017                     Membre
# 1018               Président(e)
# 1019                     Membre
# 102                Président(e)
# 1020          Vice-président(e)
# 1021                     Membre
# 1022                     Membre
# 1023                     Membre
# ...                         ...
# 972                      Membre
# 973                      Membre
# 974           Vice-président(e)
# 975           Vice-président(e)
# 976           Vice-président(e)
# 977                      Membre
# 978                      Membre
# 979        Administrateur/trice
# 98                       Membre
# 980                Président(e)
# 981             Co-Président(e)
# 982                      Membre
# 983                      Membre
# 984                Président(e)
# 985                      Membre
# 986                      Membre
# 987                      Membre
# 988                Président(e)
# 989                      Membre
# 99                       Membre
# 990                      Membre
# 991        Administrateur/trice
# 992           Aucune indication
# 993                      Membre
# 994                      Membre
# 995                      Membre
# 996                Président(e)
# 997                  Associé(e)
# 998                      Membre
# 999                      Membre
#
# [2923 rows x 6 columns]

# %% [markdown]
# Looking for names in Officers:

# %%
rs = []
for _,f,l in all_interests[['first_name','last_name']].drop_duplicates().itertuples():
    ws = f + ' ' + l
    r = search(swiss_officers, 'name', split(ws))
    if r.size > 0 or l == 'Zacharias':
        rs.append(ws)

# %%
rs
# Out:
# ['Mauro Poggia', 'Ronald Zacharias']

# %% [markdown]
# And the companies from Entities and Intermedietaries:

# %%
try:
    inters = pd.read_csv('data/all_interestsd_entities_name.csv', index_col=0)
except:
    ents = []
    for _, interest in all_interests.drop_duplicates(subset=["interest_name"]).iterrows():
        ws = split(interest["interest_name"])
        r = search(swiss_entities, 'name', ws)
        if r.size > 0:
            for idx,name in r['name'].iteritems():
                ents.append([interest["interest_name"].strip(),idx,name,interest["data_source"],interest["first_name"],interest["last_name"]])
    inters = pd.DataFrame(ents, columns=['interest_name','idx','entity_name', "data_source", "first_name", "last_name"])
    inters.to_csv('data/all_interests_entities_name.csv')

# %%
inters
# Out:
#    interest_name     idx                       entity_name  \
# 0            SVK  119433  SVK INVEST INTERNATIONAL LIMITED
# 1            SVK  150129                    SVK FOUNDATION
# 2          Aresa  173209                ARESA FINANCE LTD.
# 3           ASCA   53521              ASCA MANAGEMENT LTD.
# 4          ARGOS   31154   ARGOS BUILDING CORPORATION LTD.
# 5          ARGOS   38862                        ARGOS S.A.
# 6          ARGOS  148117                 ARGOS-REALCO S.A.
# 7          ARGOS  152462                 ARGOS (GULF) S.A.
# 8          ARGOS  164409                ARGOS TRADING LTD.
# 9          ARGOS  268869           Argos Inter Invest Ltd.
# 10           CIA    2137          J. MARQUES AND CIA. S.A.
# 11         CADES   51038                CADES FINANCE LTD.
# 12         ARGOS    3649             ARGOS HOLDING LIMITED
# 13         ARGOS   31154   ARGOS BUILDING CORPORATION LTD.
# 14         ARGOS   38862                        ARGOS S.A.
# 15         ARGOS  148117                 ARGOS-REALCO S.A.
# 16         ARGOS  152462                 ARGOS (GULF) S.A.
# 17         ARGOS  164409                ARGOS TRADING LTD.
# 18         ARGOS  190341                  ARGOS FOUNDATION
# 19         ARGOS  268869           Argos Inter Invest Ltd.
# 20        Nature   28487                NATURE ASSETS S.A.
# 21        energo   10568               ENERGO COMPANY S.A.
# 22        energo   13992      CAN-ENERGO (HOLDING) LIMITED
# 23        energo   84835               ENERGO TEHNIKA LTD.
# 24        energo  176484                 SIGMA ENERGO LTD.
#
#            data_source first_name        last_name
# 0   federal_parliament      Heinz            Brand
# 1   federal_parliament      Heinz            Brand
# 2   federal_parliament      Denis  de la Reussille
# 3    geneva_parliament      Sarah         Klopmann
# 4    geneva_parliament  Christian             Frey
# 5    geneva_parliament  Christian             Frey
# 6    geneva_parliament  Christian             Frey
# 7    geneva_parliament  Christian             Frey
# 8    geneva_parliament  Christian             Frey
# 9    geneva_parliament  Christian             Frey
# 10   geneva_parliament    Patrick           Dimier
# 11  federal_parliament    Ignazio           Cassis
# 12  federal_parliament    Liliane   Maury Pasquier
# 13  federal_parliament    Liliane   Maury Pasquier
# 14  federal_parliament    Liliane   Maury Pasquier
# 15  federal_parliament    Liliane   Maury Pasquier
# 16  federal_parliament    Liliane   Maury Pasquier
# 17  federal_parliament    Liliane   Maury Pasquier
# 18  federal_parliament    Liliane   Maury Pasquier
# 19  federal_parliament    Liliane   Maury Pasquier
# 20  federal_parliament     Robert           Cramer
# 21  federal_parliament     Martin          Landolt
# 22  federal_parliament     Martin          Landolt
# 23  federal_parliament     Martin          Landolt
# 24  federal_parliament     Martin          Landolt

# %%
scraped_interests = json.loads(open("scraped_companies_1.json").read())
scraped_interests2 = json.loads(open("data/scraped_companies.json").read())

second_order_people = []

for company in scraped_interests+scraped_interests2:
    if not "persons" in company:
        continue
    for person in company["persons"]:
        second_order_people.append({
                "first_name": person["first_name"],
                "last_name": person["last_name"],
                "source": company["source"]
            })
        
second_order_people = pd.DataFrame(second_order_people)

second_order_results = []

for _, first, last, source in second_order_people.drop_duplicates(subset=["first_name", "last_name"]).itertuples():
    full_name = first + " " + last
    results = search(swiss_officers, 'name', split(full_name))
    if results.size > 0:
        for idx,name in results['name'].iteritems():
            second_order_results.append([full_name,idx,name, source["first_name"], source["last_name"], source["data_source"], source["interest_name"]])
    #second_order_results = pd.DataFrame(second_order_results, columns=['interest_name','idx','entity_name', 'source'])

# %%
pd.DataFrame(second_order_results)
# Out:
#                 0       1                                            2  \
# 0    Peter Müller  236690                                 PETER MÜLLER
# 1   Urs Schneider  302919                            Dr. Urs Schneider
# 2     Jean Wenger  151170                             JEAN-MARC WENGER
# 3     Jean Wenger  231228                             JEAN MARC WENGER
# 4     Max Baumann  339514                          Dr Iur Max Baumann
# 5    Peter Schmid  101187                             MR. PETER SCHMID
# 6     Alois Hodel  313817                                  Alois Hodel
# 7    Walter Moser  319378                          Walter Jannik Moser
# 8  Rudolf von Arx  333291  Von Arx Rudolf and Von Arx Nicole Jeannette
#
#             3             4                   5  \
# 0      Albert        Vitali  federal_parliament
# 1  Jacqueline        Badran  federal_parliament
# 2     Daniela  Schneeberger  federal_parliament
# 3     Daniela  Schneeberger  federal_parliament
# 4       Nadja        Pieren  federal_parliament
# 5         Urs        Gasche  federal_parliament
# 6    Hansjörg        Walter  federal_parliament
# 7      Isidor       Baumann  federal_parliament
# 8         Bea          Heim  federal_parliament
#
#                                       6
# 0                  Energie Oberkirch AG
# 1                       Zugang für Alle
# 2  Schweizerischer Gewerbeverband (sgv)
# 3  Schweizerischer Gewerbeverband (sgv)
# 4                         Radio Emme AG
# 5           Stiftung Schloss Jegenstorf
# 6    Agrisano Prevos (Vorsorgestiftung)
# 7    Stiftung Historisches Erbe der SBB
# 8        Pro Senectute Kanton Solothurn

# %% [markdown]
# These matches have to be checked more in details as they seem to mean something else...
#
# ## Parlement data

# %%
parlement = pd.read_json('data/parliament_members_interests.json')

# %%
ps = []
for _,f,l in parlement[['FirstName','LastName']].drop_duplicates().itertuples():
    ws = f + ' ' + l
    r = search(swiss_officers, 'name', split(ws))
    if r.size > 0:
        ps.append(ws)

# %%
ps
# Out:
# ['Peter Schmid',
#  'Heinrich Baumann',
#  'Johann Jakob',
#  'Peter Müller',
#  'Rudolf Ott',
#  'Mauro Poggia']

# %% [markdown]
# Only some matches and there're a lot of possibilities with these names...
#
# ### Querying the Neo4j with Poggia

# %%
# %%cypher
# MATCH (o:Officer) WHERE toLower(o.name) CONTAINS "poggia"
# RETURN o.name as name, o.countries as countries LIMIT 20
# Out:
# 1 rows affected.
# [['Mauro Poggia', 'Switzerland']]

# %%
# Plotting Poggia's graph
results = %cypher \
    MATCH (o:Officer) WHERE toLower(o.name) CONTAINS "poggia" \
    match p=(o)-[r*1..100]-() \
    RETURN p limit 100
# Out:
# 15 rows affected.

# %%
G = results.get_graph()
draw(G)
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="figure/graph-4e069784-1379-463c-bde8-873c7c5e4789.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Plotting energo graph
results2 = %cypher \
    MATCH (o1:Entity) WHERE toLower(o1.name) CONTAINS "energo" \
    match p=(o1)-[r*1..100]-() \
    RETURN p limit 100
# Out:
# 100 rows affected.

# %%
G2 = results2.get_graph()
draw(G2)
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="figure/graph-29ff4b2d-044d-4464-a4e9-260c1aeac67e.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# We can see results in Morges and Porrentruy (+ Russia, Spain, Panama) all centralized around GENINT SA
# http://ge.ch/hrcintapp/externalCompanyReport.action?companyOfrcId13=CH-660-0806985-5&ofrcLanguage=2

# %%
# Plotting a graph concerning the IMD school in Lausanne ;)
results3 = %cypher \
    MATCH (o1:Address) WHERE toLower(o1.address) CONTAINS "schmidheiny" \
    match p=(o1)<-[r*1..100]-() \
    RETURN p limit 20
# Out:
# 8 rows affected.

# %%
G3 = results3.get_graph()
draw(G3)
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="figure/graph-5f0a3b78-319b-40fb-8f93-43c73d43d635.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
